# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
'
「r.text」是字符串的格式
「json.loads(r.text)」是字典的格式
'
# Out:
# '\nYour Code\n'

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json
r = requests.get('https://data.epa.gov.tw/api/v1/aqx_p_432?limit=1000&api_key=9be7b239-557b-4c10-9775-78cadfc555e9&format=json')
r.text

json.loads(r.text)
# Out:
# : '7.5',
#    'O3_8hr': '7',
#    'PM10': '65',
#    'PM2.5': '50',
#    'NO2': '23',
#    'NOx': '25.1',
#    'NO': '2.1',
#    'WindSpeed': '1.3',
#    'WindDirec': '325',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '49',
#    'PM10_AVG': '64',
#    'SO2_AVG': '3',
#    'Longitude': '120.358083',
#    'Latitude': '22.627392',
#    'SiteId': '50',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '大寮',
#    'County': '高雄市',
#    'AQI': '120',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '1.5',
#    'CO': '0.42',
#    'CO_8hr': '0.5',
#    'O3': '10.4',
#    'O3_8hr': '8',
#    'PM10': '61',
#    'PM2.5': '48',
#    'NO2': '17.8',
#    'NOx': '18.8',
#    'NO': '1.1',
#    'WindSpeed': '1.6',
#    'WindDirec': '308',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '43',
#    'PM10_AVG': '60',
#    'SO2_AVG': '3',
#    'Longitude': '120.425311',
#    'Latitude': '22.56413611',
#    'SiteId': '51',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '林園',
#    'County': '高雄市',
#    'AQI': '118',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '5.4',
#    'CO': '0.55',
#    'CO_8hr': '0.6',
#    'O3': '5.3',
#    'O3_8hr': '7',
#    'PM10': '88',
#    'PM2.5': '45',
#    'NO2': '28.4',
#    'NOx': '34.8',
#    'NO': '6.4',
#    'WindSpeed': '1.9',
#    'WindDirec': '28',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '42',
#    'PM10_AVG': '74',
#    'SO2_AVG': '3',
#    'Longitude': '120.41175',
#    'Latitude': '22.4795',
#    'SiteId': '52',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '楠梓',
#    'County': '高雄市',
#    'AQI': '115',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '1.4',
#    'CO': '0.48',
#    'CO_8hr': '0.5',
#    'O3': '19.3',
#    'O3_8hr': '16',
#    'PM10': '69',
#    'PM2.5': '45',
#    'NO2': '16.3',
#    'NOx': '18.5',
#    'NO': '2.3',
#    'WindSpeed': '2.3',
#    'WindDirec': '332',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '41',
#    'PM10_AVG': '66',
#    'SO2_AVG': '1',
#    'Longitude': '120.328289',
#    'Latitude': '22.733667',
#    'SiteId': '53',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '左營',
#    'County': '高雄市',
#    'AQI': '116',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '3',
#    'CO': '0.53',
#    'CO_8hr': '0.5',
#    'O3': '18.2',
#    'O3_8hr': '13',
#    'PM10': '77',
#    'PM2.5': '51',
#    'NO2': '18.1',
#    'NOx': '19.5',
#    'NO': '1.4',
#    'WindSpeed': '2.3',
#    'WindDirec': '344',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '41',
#    'PM10_AVG': '66',
#    'SO2_AVG': '2',
#    'Longitude': '120.292917',
#    'Latitude': '22.674861',
#    'SiteId': '54',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '前金',
#    'County': '高雄市',
#    'AQI': '113',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '2.5',
#    'CO': '0.5',
#    'CO_8hr': '0.5',
#    'O3': '15.7',
#    'O3_8hr': '13',
#    'PM10': '71',
#    'PM2.5': '45',
#    'NO2': '18.7',
#    'NOx': '20.7',
#    'NO': '2',
#    'WindSpeed': '2.3',
#    'WindDirec': '5',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '40',
#    'PM10_AVG': '64',
#    'SO2_AVG': '2',
#    'Longitude': '120.288086',
#    'Latitude': '22.632567',
#    'SiteId': '56',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '前鎮',
#    'County': '高雄市',
#    'AQI': '135',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '2',
#    'CO': '0.47',
#    'CO_8hr': '0.6',
#    'O3': '12.6',
#    'O3_8hr': '9',
#    'PM10': '72',
#    'PM2.5': '55',
#    'NO2': '20.1',
#    'NOx': '22.1',
#    'NO': '2',
#    'WindSpeed': '2',
#    'WindDirec': '17',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '49',
#    'PM10_AVG': '66',
#    'SO2_AVG': '2',
#    'Longitude': '120.307564',
#    'Latitude': '22.605386',
#    'SiteId': '57',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '小港',
#    'County': '高雄市',
#    'AQI': '122',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '3.3',
#    'CO': '0.51',
#    'CO_8hr': '0.6',
#    'O3': '6',
#    'O3_8hr': '9',
#    'PM10': '63',
#    'PM2.5': '45',
#    'NO2': '28.1',
#    'NOx': '30.3',
#    'NO': '2.1',
#    'WindSpeed': '1.2',
#    'WindDirec': '29',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '44',
#    'PM10_AVG': '65',
#    'SO2_AVG': '3',
#    'Longitude': '120.337736',
#    'Latitude': '22.565833',
#    'SiteId': '58',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '屏東',
#    'County': '屏東縣',
#    'AQI': '99',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.7',
#    'CO': '0.4',
#    'CO_8hr': '0.4',
#    'O3': '10',
#    'O3_8hr': '14',
#    'PM10': '61',
#    'PM2.5': '35',
#    'NO2': '15.4',
#    'NOx': '16.4',
#    'NO': '1',
#    'WindSpeed': '0.9',
#    'WindDirec': '69',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '35',
#    'PM10_AVG': '54',
#    'SO2_AVG': '3',
#    'Longitude': '120.488033',
#    'Latitude': '22.673081',
#    'SiteId': '59',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '潮州',
#    'County': '屏東縣',
#    'AQI': '112',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '1.2',
#    'CO': '0.44',
#    'CO_8hr': '0.5',
#    'O3': '7.3',
#    'O3_8hr': '12',
#    'PM10': '63',
#    'PM2.5': '42',
#    'NO2': '19.7',
#    'NOx': '19.9',
#    'NO': '0.3',
#    'WindSpeed': '0.7',
#    'WindDirec': '291',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '40',
#    'PM10_AVG': '62',
#    'SO2_AVG': '2',
#    'Longitude': '120.561175',
#    'Latitude': '22.523108',
#    'SiteId': '60',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '恆春',
#    'County': '屏東縣',
#    'AQI': '41',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.1',
#    'CO': '0.35',
#    'CO_8hr': '0.3',
#    'O3': '43.7',
#    'O3_8hr': '44',
#    'PM10': '16',
#    'PM2.5': '11',
#    'NO2': '2.9',
#    'NOx': '4.3',
#    'NO': '1.3',
#    'WindSpeed': '8.7',
#    'WindDirec': '34',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '9',
#    'PM10_AVG': '11',
#    'SO2_AVG': '1',
#    'Longitude': '120.788928',
#    'Latitude': '21.958069',
#    'SiteId': '61',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '臺東',
#    'County': '臺東縣',
#    'AQI': '47',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1',
#    'CO': '0.47',
#    'CO_8hr': '0.4',
#    'O3': '40.2',
#    'O3_8hr': '38',
#    'PM10': '27',
#    'PM2.5': '21',
#    'NO2': '3.5',
#    'NOx': '3.9',
#    'NO': '0.3',
#    'WindSpeed': '2.1',
#    'WindDirec': '325',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '14',
#    'PM10_AVG': '22',
#    'SO2_AVG': '1',
#    'Longitude': '121.15045',
#    'Latitude': '22.755358',
#    'SiteId': '62',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '花蓮',
#    'County': '花蓮縣',
#    'AQI': '43',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '1.3',
#    'CO': '0.42',
#    'CO_8hr': '0.4',
#    'O3': '32.9',
#    'O3_8hr': '41',
#    'PM10': '16',
#    'PM2.5': '10',
#    'NO2': '4.2',
#    'NOx': '5.1',
#    'NO': '1',
#    'WindSpeed': '1.2',
#    'WindDirec': '217',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '13',
#    'PM10_AVG': '23',
#    'SO2_AVG': '1',
#    'Longitude': '121.599769',
#    'Latitude': '23.971306',
#    'SiteId': '63',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '陽明',
#    'County': '臺北市',
#    'AQI': '52',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.8',
#    'CO': '0.22',
#    'CO_8hr': '0.3',
#    'O3': '47.7',
#    'O3_8hr': '47',
#    'PM10': '11',
#    'PM2.5': '9',
#    'NO2': '2.4',
#    'NOx': '2.7',
#    'NO': '0.3',
#    'WindSpeed': '2.5',
#    'WindDirec': '360',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '16',
#    'PM10_AVG': '19',
#    'SO2_AVG': '1',
#    'Longitude': '121.529583',
#    'Latitude': '25.182722',
#    'SiteId': '64',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '宜蘭',
#    'County': '宜蘭縣',
#    'AQI': '64',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.9',
#    'CO': '0.4',
#    'CO_8hr': '0.5',
#    'O3': '28.8',
#    'O3_8hr': '37',
#    'PM10': '',
#    'PM2.5': '12',
#    'NO2': '3.5',
#    'NOx': '4.2',
#    'NO': '0.7',
#    'WindSpeed': '1.1',
#    'WindDirec': '276',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '21',
#    'PM10_AVG': '',
#    'SO2_AVG': '2',
#    'Longitude': '121.746394',
#    'Latitude': '24.747917',
#    'SiteId': '65',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '冬山',
#    'County': '宜蘭縣',
#    'AQI': '71',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.5',
#    'CO': '0.34',
#    'CO_8hr': '0.4',
#    'O3': '36.5',
#    'O3_8hr': '38',
#    'PM10': '22',
#    'PM2.5': '18',
#    'NO2': '3.1',
#    'NOx': '3.9',
#    'NO': '0.8',
#    'WindSpeed': '1.8',
#    'WindDirec': '249',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '24',
#    'PM10_AVG': '31',
#    'SO2_AVG': '2',
#    'Longitude': '121.792928',
#    'Latitude': '24.632203',
#    'SiteId': '66',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '三重',
#    'County': '新北市',
#    'AQI': '97',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2',
#    'CO': '0.75',
#    'CO_8hr': '1',
#    'O3': '-',
#    'O3_8hr': '-',
#    'PM10': '39',
#    'PM2.5': '24',
#    'NO2': '29.8',
#    'NOx': '53.9',
#    'NO': '24.1',
#    'WindSpeed': '-',
#    'WindDirec': '-',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '34',
#    'PM10_AVG': '50',
#    'SO2_AVG': '2',
#    'Longitude': '121.493806',
#    'Latitude': '25.072611',
#    'SiteId': '67',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '中壢',
#    'County': '桃園市',
#    'AQI': '121',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '6',
#    'CO': '0.62',
#    'CO_8hr': '1',
#    'O3': '23.3',
#    'O3_8hr': '20',
#    'PM10': '50',
#    'PM2.5': '37',
#    'NO2': '18',
#    'NOx': '18.6',
#    'NO': '0.7',
#    'WindSpeed': '0.6',
#    'WindDirec': '351',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '43',
#    'PM10_AVG': '60',
#    'SO2_AVG': '2',
#    'Longitude': '121.221667',
#    'Latitude': '24.953278',
#    'SiteId': '68',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '竹山',
#    'County': '南投縣',
#    'AQI': '102',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '2',
#    'CO': '0.53',
#    'CO_8hr': '0.5',
#    'O3': '25',
#    'O3_8hr': '20',
#    'PM10': '59',
#    'PM2.5': '39',
#    'NO2': '10',
#    'NOx': '9.6',
#    'NO': '0',
#    'WindSpeed': '1.7',
#    'WindDirec': '26',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '36',
#    'PM10_AVG': '56',
#    'SO2_AVG': '2',
#    'Longitude': '120.677306',
#    'Latitude': '23.756389',
#    'SiteId': '69',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '永和',
#    'County': '新北市',
#    'AQI': '95',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2',
#    'CO': '0.4',
#    'CO_8hr': '0.7',
#    'O3': '31',
#    'O3_8hr': '30',
#    'PM10': '33',
#    'PM2.5': '24',
#    'NO2': '7.5',
#    'NOx': '8.7',
#    'NO': '1.2',
#    'WindSpeed': '0.8',
#    'WindDirec': '164',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '34',
#    'PM10_AVG': '48',
#    'SO2_AVG': '3',
#    'Longitude': '121.516306',
#    'Latitude': '25.017',
#    'SiteId': '70',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '復興',
#    'County': '高雄市',
#    'AQI': '130',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '2.9',
#    'CO': '0.53',
#    'CO_8hr': '0.6',
#    'O3': '13.9',
#    'O3_8hr': '10',
#    'PM10': '75',
#    'PM2.5': '47',
#    'NO2': '19.8',
#    'NOx': '22.1',
#    'NO': '2.3',
#    'WindSpeed': '1.2',
#    'WindDirec': '114',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '47',
#    'PM10_AVG': '69',
#    'SO2_AVG': '3',
#    'Longitude': '120.312017',
#    'Latitude': '22.608711',
#    'SiteId': '71',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '埔里',
#    'County': '南投縣',
#    'AQI': '61',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '1.1',
#    'CO': '0.37',
#    'CO_8hr': '0.4',
#    'O3': '8.1',
#    'O3_8hr': '16',
#    'PM10': '25',
#    'PM2.5': '19',
#    'NO2': '9.3',
#    'NOx': '10.1',
#    'NO': '0.9',
#    'WindSpeed': '0.6',
#    'WindDirec': '81',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '20',
#    'PM10_AVG': '26',
#    'SO2_AVG': '2',
#    'Longitude': '120.967903',
#    'Latitude': '23.968842',
#    'SiteId': '72',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '馬祖',
#    'County': '連江縣',
#    'AQI': '126',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '3.5',
#    'CO': '0.42',
#    'CO_8hr': '0.4',
#    'O3': '47.4',
#    'O3_8hr': '49',
#    'PM10': '62',
#    'PM2.5': '43',
#    'NO2': '6.4',
#    'NOx': '7.2',
#    'NO': '0.8',
#    'WindSpeed': '2.3',
#    'WindDirec': '321',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '45',
#    'PM10_AVG': '65',
#    'SO2_AVG': '4',
#    'Longitude': '119.949875',
#    'Latitude': '26.160469',
#    'SiteId': '75',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '金門',
#    'County': '金門縣',
#    'AQI': '99',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '2.5',
#    'CO': '0.47',
#    'CO_8hr': '0.4',
#    'O3': '42.2',
#    'O3_8hr': '46',
#    'PM10': '75',
#    'PM2.5': '50',
#    'NO2': '10.4',
#    'NOx': '10.9',
#    'NO': '0.3',
#    'WindSpeed': '3.6',
#    'WindDirec': '44',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '35',
#    'PM10_AVG': '57',
#    'SO2_AVG': '3',
#    'Longitude': '118.312256',
#    'Latitude': '24.432133',
#    'SiteId': '77',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '馬公',
#    'County': '澎湖縣',
#    'AQI': '97',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.5',
#    'CO': '0.32',
#    'CO_8hr': '0.4',
#    'O3': '43.7',
#    'O3_8hr': '52',
#    'PM10': '52',
#    'PM2.5': '28',
#    'NO2': '4',
#    'NOx': '5.6',
#    'NO': '1.6',
#    'WindSpeed': '7.6',
#    'WindDirec': '24',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '34',
#    'PM10_AVG': '53',
#    'SO2_AVG': '1',
#    'Longitude': '119.566158',
#    'Latitude': '23.569031',
#    'SiteId': '78',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '關山',
#    'County': '臺東縣',
#    'AQI': '37',
#    'Pollutant': '',
#    'Status': '良好',
#    'SO2': '0.5',
#    'CO': '-',
#    'CO_8hr': '-',
#    'O3': '36.6',
#    'O3_8hr': '37',
#    'PM10': '20',
#    'PM2.5': '17',
#    'NO2': '3',
#    'NOx': '4.1',
#    'NO': '1.1',
#    'WindSpeed': '1.3',
#    'WindDirec': '27',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '12',
#    'PM10_AVG': '15',
#    'SO2_AVG': '1',
#    'Longitude': '121.161933',
#    'Latitude': '23.045083',
#    'SiteId': '80',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '麥寮',
#    'County': '雲林縣',
#    'AQI': '118',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '5.2',
#    'CO': '0.45',
#    'CO_8hr': '0.5',
#    'O3': '27.2',
#    'O3_8hr': '32',
#    'PM10': '49',
#    'PM2.5': '37',
#    'NO2': '13.5',
#    'NOx': '16.5',
#    'NO': '2.9',
#    'WindSpeed': '5.4',
#    'WindDirec': '8',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '42',
#    'PM10_AVG': '59',
#    'SO2_AVG': '3',
#    'Longitude': '120.251825',
#    'Latitude': '23.753506',
#    'SiteId': '83',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '富貴角',
#    'County': '新北市',
#    'AQI': '87',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.5',
#    'CO': '0.24',
#    'CO_8hr': '0.3',
#    'O3': '57.3',
#    'O3_8hr': '55',
#    'PM10': '65',
#    'PM2.5': '27',
#    'NO2': '2',
#    'NOx': '1.9',
#    'NO': '0',
#    'WindSpeed': '10.7',
#    'WindDirec': '48',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '30',
#    'PM10_AVG': '73',
#    'SO2_AVG': '0',
#    'Longitude': '121.54738',
#    'Latitude': '25.29228',
#    'SiteId': '84',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '彰化(員林)',
#    'County': '彰化縣',
#    'AQI': '106',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '2.2',
#    'CO': '0.5',
#    'CO_8hr': '0.5',
#    'O3': '32.8',
#    'O3_8hr': '36',
#    'PM10': '59',
#    'PM2.5': '39',
#    'NO2': '11.8',
#    'NOx': '11.5',
#    'NO': '0',
#    'WindSpeed': '1',
#    'WindDirec': '5',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '37',
#    'PM10_AVG': '58',
#    'SO2_AVG': '2',
#    'Longitude': '120.58178611',
#    'Latitude': '23.95058333',
#    'SiteId': '201',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '彰化(大城)',
#    'County': '彰化縣',
#    'AQI': '106',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '2.9',
#    'CO': '0.14',
#    'CO_8hr': '0.2',
#    'O3': '43.3',
#    'O3_8hr': '43',
#    'PM10': '57',
#    'PM2.5': '23',
#    'NO2': '8.8',
#    'NOx': '10.1',
#    'NO': '1.3',
#    'WindSpeed': '6.5',
#    'WindDirec': '22',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '37',
#    'PM10_AVG': '67',
#    'SO2_AVG': '2',
#    'Longitude': '120.27311',
#    'Latitude': '23.84313',
#    'SiteId': '202',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '臺南(麻豆)',
#    'County': '臺南市',
#    'AQI': '125',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '1',
#    'CO': '0.56',
#    'CO_8hr': '0.5',
#    'O3': '21.5',
#    'O3_8hr': '28',
#    'PM10': '69',
#    'PM2.5': '52',
#    'NO2': '14.1',
#    'NOx': '14.8',
#    'NO': '0.7',
#    'WindSpeed': '2.1',
#    'WindDirec': '10',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '45',
#    'PM10_AVG': '63',
#    'SO2_AVG': '1',
#    'Longitude': '120.24583056',
#    'Latitude': '23.17904722',
#    'SiteId': '203',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '屏東(琉球)',
#    'County': '屏東縣',
#    'AQI': '104',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '3.5',
#    'CO': '0.81',
#    'CO_8hr': '0.5',
#    'O3': '0.5',
#    'O3_8hr': '14',
#    'PM10': '77',
#    'PM2.5': '49',
#    'NO2': '40.1',
#    'NOx': '45.1',
#    'NO': '5',
#    'WindSpeed': '1.3',
#    'WindDirec': '311',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '37',
#    'PM10_AVG': '65',
#    'SO2_AVG': '3',
#    'Longitude': '120.37722',
#    'Latitude': '22.35222',
#    'SiteId': '204',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '臺南(北門)',
#    'County': '臺南市',
#    'AQI': '112',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '1.1',
#    'CO': '0.48',
#    'CO_8hr': '0.5',
#    'O3': '26.8',
#    'O3_8hr': '30',
#    'PM10': '',
#    'PM2.5': '39',
#    'NO2': '11.3',
#    'NOx': '11.6',
#    'NO': '0.3',
#    'WindSpeed': '3.1',
#    'WindDirec': '20',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '40',
#    'PM10_AVG': '64',
#    'SO2_AVG': '1',
#    'Longitude': '120.12444444',
#    'Latitude': '23.26472222',
#    'SiteId': '310',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '新北(樹林)',
#    'County': '新北市',
#    'AQI': '107',
#    'Pollutant': '細懸浮微粒',
#    'Status': '對敏感族群不健康',
#    'SO2': '0.5',
#    'CO': '0.39',
#    'CO_8hr': '0.5',
#    'O3': '16.9',
#    'O3_8hr': '20',
#    'PM10': '-',
#    'PM2.5': '29',
#    'NO2': '15.7',
#    'NOx': '15.8',
#    'NO': '0.3',
#    'WindSpeed': '0',
#    'WindDirec': '193',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '38',
#    'PM10_AVG': '-',
#    'SO2_AVG': '1',
#    'Longitude': '121.38352778',
#    'Latitude': '24.94902778',
#    'SiteId': '311',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '桃園(竹圍)',
#    'County': '桃園市',
#    'AQI': '84',
#    'Pollutant': '細懸浮微粒',
#    'Status': '普通',
#    'SO2': '0.5',
#    'CO': '0.24',
#    'CO_8hr': '0.3',
#    'O3': '43.4',
#    'O3_8hr': '38',
#    'PM10': '57',
#    'PM2.5': '26',
#    'NO2': '4.5',
#    'NOx': '4.6',
#    'NO': '0.3',
#    'WindSpeed': '2.1',
#    'WindDirec': '37',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '29',
#    'PM10_AVG': '64',
#    'SO2_AVG': '1',
#    'Longitude': '121.24426111',
#    'Latitude': '25.10363611',
#    'SiteId': '312',
#    'ImportDate': '2020-12-25 04:45:02.143000'},
#   {'SiteName': '屏東(枋寮)',
#    'County': '屏東縣',
#    'AQI': '105',
#    'Pollutant': '二氧化硫',
#    'Status': '對敏感族群不健康',
#    'SO2': '84.6',
#    'CO': '0.42',
#    'CO_8hr': '0.4',
#    'O3': '4.2',
#    'O3_8hr': '7',
#    'PM10': '74',
#    'PM2.5': '38',
#    'NO2': '23.1',
#    'NOx': '24.7',
#    'NO': '1.6',
#    'WindSpeed': '0.2',
#    'WindDirec': '47',
#    'PublishTime': '2020/12/25 04:00:00',
#    'PM2.5_AVG': '34',
#    'PM10_AVG': '63',
#    'SO2_AVG': '8',
#    'Longitude': '120.59116667',
#    'Latitude': '22.37094722',
#    'SiteId': '313',
#    'ImportDate': '2020-12-25 04:45:02.143000'}],
#  'limit': 1000,
#  'offset': 0,
#  '_links': {'start': '/api/v1/aqx_p_432?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&limit=1000&format=json',
#   'next': '/api/v1/aqx_p_432?api_key=9be7b239-557b-4c10-9775-78cadfc555e9&limit=1000&offset=1000&format=json'},
#  'total': 85}
