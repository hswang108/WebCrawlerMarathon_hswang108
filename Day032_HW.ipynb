# %% [markdown]
# # 反爬：驗證碼處理
#
# * 了解「驗證碼機制」的反爬蟲機制
# * 「驗證碼機制」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 讀讀看「test」資料夾下的圖檔！
# * 像 test/test2.png 這種複雜的圖片怎麼辦？

# %% [markdown]
# ### 讀讀看「test」資料夾下的圖檔！

# %%
import requests
import pytesseract
from PIL import Image
from io import BytesIO

# %%
! pipenv --python 3.7
! pipenv shell
! pipenv install Pillow opencv-python pytesseract
# Out:
# 'pipenv' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC
# 'pipenv' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC
# 'pipenv' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %%
img = Image.open('./test1.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=954x362 at 0x17F1BB3D400>

# %% [markdown]
# ### 像 test/test2.png 這種複雜的圖片怎麼辦？

# %%
img = Image.open("test2.png").convert("L")
img
# Out:
# <PIL.Image.Image image mode=L size=154x64 at 0x17F1BAE5070>

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
code = pytesseract.image_to_string(img)
print(code)
# Out:
# 4413

# %%
# 定義黑白閾值，大於這個數值為黑色，小於這個數值為白色
threshold = 120

table = []
for i in range(256):
    if i < threshold:
        table.append(0)
    else:
        table.append(1)

# 圖片二值化
img_th = img.point(table, '1')
display(img_th)

code = pytesseract.image_to_string(img_th)
print(code)
# Out:
# <PIL.Image.Image image mode=1 size=154x64 at 0x17F1BB3D9A0>
# 1413
